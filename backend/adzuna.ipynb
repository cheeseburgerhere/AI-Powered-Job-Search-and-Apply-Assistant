# %%
from .services.job_search import JobSearchService

ser=JobSearchService()

search_result = ser.search_jobs(
    query="job",
    location="nz",
    remote_only=False,
    salary_min=0,
    salary_max=1000000,
    page=max(1, 4),
    per_page=max(1, min(15, 100)),
    sources="adzuna",
    country="nz",
)
